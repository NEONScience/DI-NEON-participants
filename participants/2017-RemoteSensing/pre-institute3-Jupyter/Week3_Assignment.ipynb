# %% [markdown]
# # Week 3 Assignment
# ## Neon summer institute
# ************************************
# ### Marja Haagsma
#
# 1. Checking for version, this should be 3.4
# 2. Checking if *import gdal* works
# 3. Importing pyplot module to plot the geotiff

# %%
import sys
import gdal
from matplotlib import pyplot as plt

sys.version
# Out:
# '3.4.5 |Anaconda custom (64-bit)| (default, Jul  5 2016, 14:53:07) [MSC v.1600 64 bit (AMD64)]'

# %% [markdown]
# Opening the GeoTifF and checking size

# %%
SJER_DTM_17 = gdal.Open('NEON_D17_SJER_DP3_252000_4109000_DTM.tif')
SJER_DTM_17.RasterXSize
# Out:
# 1000

# %% [markdown]
# Converting the osgeo.gdal.Dataset to a numpy array

# %%
SJER=SJER_DTM_17.ReadAsArray()
type(SJER)
# Out:
# numpy.ndarray

# %% [markdown]
# Plot the **DTM**

# %%
plt.imshow(SJER)
plt.show()
