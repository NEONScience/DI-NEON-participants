# %% [markdown]
# ## NEON pre-institute week 3 assignment
#    * import a TIFF file with gdal

# %%
import sys

# %%
sys.version
# Out:
# '3.5.3 |Anaconda custom (x86_64)| (default, Mar  6 2017, 12:15:08) \n[GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]'

# %%
import gdal

# %% [markdown]
# I downloaded the TIFF file from the link given, and saved it in my DI-NEON-Participants/participants/2017-RemoteSensing/pre-institute3-jupyter folder on my laptop

# %%
tif = gdal.Open('NEON_D17_SJER_DP3_252000_4109000_DTM.tif')
band1 = tif.GetRasterBand(1)
band1Array = band1.ReadAsArray()

# %% [markdown]
# Checking now the size of the raster

# %%
print("X",tif.RasterXSize)
print("Y",tif.RasterYSize)
# Out:
# X 1000
# Y 1000

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
plt.style.use("bmh")

## setup figure
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.set_ylabel("something")
ax.set_xlabel("something else")
imgplot = ax.imshow(band1Array)
plt.show()
